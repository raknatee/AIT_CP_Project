# %%
import pickle
import os
import json

# %%
des_path = r"/home/jovyan/work/root/datasets/001_json_version"
filenames = os.listdir("./root/ori_datasets")
print(filenames)
# Out:
# ['s01.dat', 's02.dat', 's03.dat', 's04.dat', 's05.dat', 's06.dat', 's07.dat', 's08.dat', 's09.dat', 's10.dat', 's11.dat', 's12.dat', 's13.dat', 's14.dat', 's15.dat', 's16.dat', 's17.dat', 's18.dat', 's19.dat', 's20.dat', 's21.dat', 's22.dat', 's23.dat', 's24.dat', 's25.dat', 's26.dat', 's27.dat', 's28.dat', 's29.dat', 's30.dat', 's31.dat', 's32.dat']

# %%
def create_filename(i,max_digi=2):
    d = len(str(i))
    if(d<max_digi):
        return '0'*(max_digi-d)+str(i)
    


for i,filename in enumerate(filenames):
    
    with open(f"./root/ori_datasets/{filename}","rb") as f:

     

        data = pickle.load(f,encoding='bytes')

    break
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# {'data': array([[[-1.11163104e+01,  7.18124410e+01,  1.22849624e+02, ...,
#          -5.89884788e+01, -4.73678399e+01, -2.12020108e+01],
#         [ 1.75659861e+01, -1.53853133e+02, -2.53610232e+02, ...,
#           1.03480282e+02,  1.06308826e+02,  8.30637609e+01],
#         [ 8.79215594e+00,  1.96108361e+01,  1.63720087e+01, ...,
#          -9.66732098e+00, -9.45398407e+00, -7.48393557e+00],
#         ...,
#         [-2.98172952e+02, -3.22110407e+02, -3.18329164e+02, ...,
#          -1.72957656e+03, -1.72938906e+03, -1.73557655e+03],
#         [ 3.85814397e+03,  3.77757879e+03,  3.71361492e+03, ...,
#           8.82584191e+03,  8.69547279e+03,  8.67105910e+03],
#         [ 1.61612512e-02,  1.61612512e-02,  1.61612512e-02, ...,
#          -5.48378389e-02, -5.38378517e-02, -5.48378389e-02]],
#
#        [[ 9.01476632e+00,  8.79861207e+00,  2.00388299e+01, ...,
#          -1.69939703e+01, -6.55141501e+00,  8.16343155e+00],
#         [-3.01154138e+01, -3.26355445e+01, -6.06414696e+01, ...,
#           3.17974759e+01,  1.66846399e+01, -1.72515455e+01],
#         [-3.07245566e-01,  2.43314250e+00,  7.26527820e+00, ...,
#          -5.74841562e+00, -9.17131404e-01,  5.70627080e+00],
#         ...,
#         [-7.46366785e+02, -7.46241785e+02, -7.05648110e+02, ...,
#          -2.39586374e+03, -2.37786377e+03, -2.39286374e+03],
#         [ 8.55978353e+02,  8.34982579e+02,  8.71603116e+02, ...,
#          -1.83978145e+03, -1.86175378e+03, -1.85638276e+03],
#         [ 2.52366558e-02,  2.52366558e-02,  2.52366558e-02, ...,
#          -4.47624472e-02, -4.47624472e-02, -4.47624472e-02]],
#
#        [[-7.10697177e+01, -5.44457016e+01, -3.73802655e+01, ...,
#           1.20673393e+02,  1.02971692e+02,  1.00742193e+02],
#           5.36912836e+01,  1.14275578e+02,  1.93485144e+02],
#         [ 1.27351924e+00,  3.52006312e-01, -3.36934080e+00, ...,
#          -3.08719784e+00, -5.29773267e+00, -1.27875147e+01],
#         ...,
#         [-7.34480251e+01, -5.29480630e+01, -4.99793185e+01, ...,
#          -1.94994456e+03, -1.98497574e+03, -1.81241356e+03],
#         [ 3.65582441e+03,  3.46100315e+03,  3.39166827e+03, ...,
#          -8.69009161e+02, -9.40785414e+02, -1.03502226e+03],
#         [ 4.25254967e-03,  4.25254967e-03,  4.25254967e-03, ...,
#          -4.07468737e-02, -4.07468737e-02, -4.17468608e-02]]]), 'labels': array([[9.  , 5.03, 7.13, 6.62],
#        [8.01, 7.1 , 8.04, 8.08],
#        [9.  , 9.  , 8.96, 8.05],
#        [6.05, 1.  , 5.04, 7.03],
#        [5.04, 3.  , 3.65, 5.04],
#        [5.  , 4.94, 5.04, 1.01],
#        [4.96, 1.99, 4.08, 1.  ],
#        [9.  , 9.  , 9.  , 9.  ],
#        [9.  , 7.  , 9.  , 7.18],
#        [4.99, 1.  , 9.  , 1.  ],
#        [7.08, 1.  , 7.01, 7.  ],
#        [8.01, 6.06, 7.12, 9.  ],
#        [9.  , 4.99, 9.  , 9.  ],
#        [8.94, 9.  , 8.97, 9.  ],
#        [9.  , 8.01, 8.06, 9.  ],
#        [6.  , 5.05, 8.05, 6.14],
#        [9.  , 3.  , 6.03, 7.41],
#        [9.  , 6.15, 9.  , 8.08],
#        [9.  , 8.32, 8.06, 6.99],
#        [8.97, 9.  , 8.03, 9.  ],
#        [1.  , 1.  , 5.04, 1.  ],
#        [5.  , 1.  , 4.97, 5.  ],
#        [1.  , 2.97, 1.  , 7.82],
#        [7.08, 9.  , 6.06, 9.  ],
#        [9.  , 9.  , 8.1 , 9.  ],
#        [9.  , 8.04, 9.  , 9.  ],
#        [4.96, 5.01, 3.01, 5.05],
#        [4.06, 4.97, 7.14, 7.04],
#        [2.99, 7.04, 7.03, 9.  ],
#        [2.01, 7.05, 1.  , 7.13],
#        [4.06, 7.05, 1.  , 9.  ],
#        [1.  , 9.  , 2.01, 1.  ],
#        [5.  , 8.03, 3.01, 1.  ],
#        [4.87, 1.  , 6.99, 1.  ],
#        [1.99, 2.  , 1.  , 1.  ],
#        [5.04, 1.  , 7.09, 1.  ],
#        [1.  , 8.06, 1.  , 1.  ],
#        [1.  , 9.  , 1.  , 1.  ],
#        [1.  , 1.  , 2.97, 1.  ],
#        [6.05, 6.67, 6.94, 6.53]])}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-45f949a0d0ce> in <module>
#      15
#      16             temp['data'] = data[b'data']
# ---> 17             print(temp['data'].tolist())
#      18             temp['labels'] = data[b'labels']
#      19             print(temp)
#
# KeyboardInterrupt:
