# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from my_modules.load_data import MyDataset
train_index_movie = [i for i in range(38)]
test_index_movie = [i for i in range(len(train_index_movie),40)]

data_path = r'C:\Users\rakna\Desktop\AIT_working\AIT_CP_Project\this_folder_git_ignore\ori_datasets\s01.dat'
window_size = 145*10
step_window = 10

data_train = MyDataset(data_path,window_size,step_window,train_index_movie,do_noise=True)
data_test = MyDataset(data_path,window_size,step_window,test_index_movie)

# %%
fs = 8064//55
ds = 1/fs

# %%
sample_signal = data_train[1][0][1]
sample_signal
# Out:
# tensor([ -6.1821, -10.0808,  -8.8482,  ...,  -2.9472,  -4.2250,  -1.6156])

# %%
plt.plot(sample_signal)

# %%
def fft(signal,delta_time):
    fourier_transform = np.fft.fft(sample_signal)/len(sample_signal)
    fourier_transform = np.abs(fourier_transform[:fourier_transform.size])
#     fourier_transform = np.abs(fourier_transform[:fourier_transform.size//2])
    frequency_series = np.arange(fourier_transform.shape[0])/delta_time
    return frequency_series,fourier_transform

output = fft(sample_signal,ds)
print(sample_signal.shape)
print(output[1].shape)
plt.plot(output[0],output[1])
plt.show()
# Out:
# torch.Size([1450])
# (1450,)

# %%
import torch
x = torch.randn(4, 3, 2)
torch.fft(x, 2)
# Out:
# tensor([[[ 0.5721, -3.4014],
#          [ 0.6142, -1.7370],
#          [-0.7926, -0.5252]],
#
#         [[ 5.5501,  4.1583],
#          [ 1.1691, -2.4631],
#          [-1.0735, -3.4002]],
#
#         [[ 2.1581, -3.5671],
#          [-3.1006, -2.5449],
#          [ 0.5599, -1.8210]],
#
#         [[-3.0109, -2.8055],
#          [ 0.3536, -4.2256],
#          [-6.1991, -2.6631]]])

# %%
import torch

d = [data_train[0][0],data_train[1][0],data_train[2][0]]
data_set =torch.cat( [torch.unsqueeze(e,0) for e in d] ,0)

output = torch.rfft(data_set,1,onesided =False)
print(data_set.shape)
# print(data_set[:,1,:5])
print(output.shape)
# print(output[:,1,:5])
print(output[0,0,:,1].shape)
plt.plot(output[0,0,:,0]+output[0,0,:,1])
# Out:
# torch.Size([3, 40, 1450])
# torch.Size([3, 40, 1450, 2])
# torch.Size([1450])

# %%
input_stft = data_set[0,0,:]
print(input_stft.shape)
output = torch.stft(input_stft,n_fft=145)
print(output.shape)
print(output)
plt.plot(output.flatten())
# Out:
# torch.Size([1450])
# torch.Size([73, 41, 2])
# tensor([[[ 9.9487e+00,  0.0000e+00],
#          [-1.7605e+01,  0.0000e+00],
#          [-7.2183e+00,  0.0000e+00],
#          ...,
#          [-2.8197e+01,  0.0000e+00],
#          [-3.1653e+00,  0.0000e+00],
#          [ 1.8236e+01,  0.0000e+00]],
#
#         [[ 2.7125e+01,  5.8779e-01],
#          [-6.8124e+00,  7.6670e+00],
#          [-3.9827e+00,  2.7288e+00],
#          ...,
#          [-2.9737e+01,  2.1967e+00],
#          [-1.2031e+01,  1.0633e+01],
#          [-3.4146e+00, -6.4576e-01]],
#
#         [[ 1.3548e+01,  5.8745e-01],
#          [ 1.4201e+00,  4.5756e+00],
#          [-7.3660e+00,  1.2287e+00],
#          ...,
#          [-3.0258e+01,  2.5739e+00],
#          [-2.7599e+01,  1.0515e+01],
#          [ 1.5817e+01, -1.9115e+01]],
#
#         ...,
#
#         [[ 1.4943e-01,  2.7560e+00],
#          [ 2.8615e+00, -2.8225e+00],
#          [ 1.1379e+00,  4.2521e-01],
#          ...,
#          [ 4.5774e-01, -1.2374e+00],
#          [ 1.2108e+00,  3.4241e-01],
#          [-6.1804e+00,  1.9987e-02]],
#
#         [[-1.8789e-01, -5.7792e+00],
#          [ 1.5325e+00,  2.4657e+00],
#          [ 2.9364e+00, -7.8081e-01],
#          ...,
#          [-5.3480e-02,  1.2842e-01],
#          [ 1.6008e+00, -1.1769e+00],
#          [-6.6572e+00,  9.8568e-01]],
#
#         [[ 1.5543e-02,  1.4344e+00],
#          [ 8.0226e+00,  6.9378e-02],
#          [ 2.8175e+00, -3.0581e+00],
#          ...,
#          [ 4.6147e-01, -1.6724e-01],
#          [ 2.5410e+00, -1.0022e+00],
#          [-5.7754e+00, -1.2816e+00]]])
